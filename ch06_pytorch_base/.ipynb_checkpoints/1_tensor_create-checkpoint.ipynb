# %%
import torch

# %% [markdown]
# 1.基本张量创建
# （1）按内容创建张量

# %%
tensor1 = torch.tensor(10)
print(tensor1)
print(tensor1.size())
print(tensor1.dtype)
# Out:
# tensor(10)
# torch.Size([])
# torch.int64
