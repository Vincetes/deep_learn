# %%
import torch

# %%
x = torch.randn(3, 5)
print(x)
# Out:
# tensor([[-0.2921,  0.4631, -0.1964, -1.0140, -0.6986],
#         [-1.7891,  1.6983, -1.0965, -0.4056,  0.4063],
#         [ 0.1947, -0.9881,  0.8766,  1.5184, -0.6500]])

# %%
y = torch.softmax(x, dim=1)  #指定维度 这里选几就是跨哪个列
print(y)
# Out:
# tensor([[0.1859, 0.3955, 0.2045, 0.0903, 0.1238],
#         [0.0205, 0.6718, 0.0411, 0.0820, 0.1846],
#         [0.1338, 0.0410, 0.2647, 0.5029, 0.0575]])

# %%
#计算损失
